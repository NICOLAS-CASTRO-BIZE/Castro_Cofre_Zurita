# %%
from langchain_community.document_loaders import PyPDFLoader

# Paso 1: Definir la ruta del archivo PDF

# Ruta del archivo PDF (asegúrate de que el archivo esté en la misma carpeta o usa una ruta completa)
ruta_pdf = "../data/biblioteca-de-alimentos2.pdf"

# %%
# Paso 2: Cargar el archivo PDF con PyPDFLoader
loader = PyPDFLoader(ruta_pdf)

# %%
# Extraer las páginas del PDF
documento = loader.load()

# %%
# Concatenar el texto de todas las páginas en un solo string
texto_pdf = "\n".join([page.page_content for page in documento])

# %%
#Paso 3: Exportar el texto extraído a un archivo .txt
ruta_txt = "archivo_extraido.txt"
with open(ruta_txt, "w", encoding="utf-8") as archivo_txt:
    archivo_txt.write(texto_pdf)

# %%
# Confirmación
print(f"El texto extraído del PDF se ha guardado en el archivo: {ruta_txt}")
# Out:
# El texto extraído del PDF se ha guardado en el archivo: archivo_extraido.txt

# %% [markdown]
# ## Recursive Character Splitter

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 215, chunk_overlap=0)

# %%
text_splitter.create_documents([texto_pdf])
# Out:
# [Document(metadata={}, page_content='BIBLIOTECA DE \nALIMENTOS \nAtualizada em 06.11.2024 \nCoordenação de Processos Regulatórios – CPROR \nAssessoria de Melhoria da Qualidade Regulatória – ASREG \nGabinete do Diretor-Presidente'),
#  Document(metadata={}, page_content='AGENDA REGULATÓRIA \nCiclo Bienal \n2024-2025 \n \n \nAPRESENTAÇÃO \n \n As Bibliotecas são documentos que reúnem todas as normas vigentes de determinado'),
#  Document(metadata={}, page_content='macrotema, divididos por temas. O objetivo é facilitar o acesso e a compreensão do Estoque \nRegulatório ao público interno e externo, bem como aprimorar o processo de elaboração e \nrevisão das normativas.'),
#  Document(metadata={}, page_content='Não deixe de consultar também a Biblioteca de Temas Transversais, que abrange assuntos \naplicados a todos os macrotemas, tais como: Autorização de Funcionamento de Empresa'),
#  Document(metadata={}, page_content='(AFE), Certificação de Boas Práticas de Fabricação (CBPF), Taxas de Fiscalização de Vigilância \nSanitária (TFVS), Peticionamento de Recursos, etc.'),
#  Document(metadata={}, page_content='No setor de alimentos, a Anvisa coordena, supervisiona e controla as atividades de registro, inspeção, \nfiscalização e controle de riscos, sendo responsável por estabelecer normas e padrões de qualidade e'),
#  Document(metadata={}, page_content='identidade a serem observados. \nO objetivo é garantir a segurança e a qualidade de alimentos, incluindo bebidas, águas envasadas,'),
#  Document(metadata={}, page_content='ingredientes, matérias-primas, aditivos alimentares e coadjuvantes de tecnologia, materiais em contato \ncom alimentos, contaminantes, resíduos de medicamentos veterinários, rotulagem e inovações'),
#  Document(metadata={}, page_content='tecnológicas em produtos da área de alimentos. \n \n \n1. Regularização, avaliação de risco e padrões de alimentos'),
#  Document(metadata={}, page_content='Lei 9.782/1999 – Define o Sistema Nacional de Vigilância Sanitária, cria a Agência Nacional de Vigilância \nSanitária, e dá outras providências. \n \nDecreto-Lei 986/1969 – Institui normas básicas sobre alimentos'),
#  Document(metadata={}, page_content='RDC 204/2005 – Procedimento de petições submetidas à análise pelos setores técnicos da Anvisa \nAlterada por: \nRDC 23/2015 \nRDC 208/2018'),
#  Document(metadata={}, page_content='RDC 25/2011 – Procedimentos gerais para utilização dos serviços de protocolo de documentos no âmbito da \nAnvisa \nAlterada por: \nRDC 50/2013  \nAtos relacionados:'),
#  Document(metadata={}, page_content='RDC 470/2021 - Procedimentos para o recebimento de documentos em suporte eletrônico. \nIN 50/2019 - Lista de assuntos de petição a serem protocoladas em suporte eletrônico.  \nAlterada por: \nRDC 472/2021'),
#  Document(metadata={}, page_content='RDC 702/2022 - Revoga Resoluções de Diretoria Colegiada - RDC, em virtude da publicação da Portaria GM/MS \nnº 913, de 22 de abril de 2022, do Ministro de Estado da Saúde, que declara o encerramento da Emergência'),
#  Document(metadata={}, page_content='em Saúde Pública de Importância Nacional (ESPIN) em decorrência da infecção humana pelo novo coronavírus \n(2019-nCoV). \n1.1. Procedimentos para regularização de alimentos'),
#  Document(metadata={}, page_content='Tema Regulatório 3.22 da Agenda Regulatória 2024/2025: Revisão da regulamentação sobre regularização  \nde alimentos dispensados de registro.'),
#  Document(metadata={}, page_content='RDC 20/2008 - Embalagens de polietileno  tereftalato (PET) pós-consumo reciclado grau alimentício (PET -PCR \ngrau alimentício) destinados a entrar em contato com alimentos. \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de \nVigilância Sanitária (SNVS) destinados à oferta no território nacional.'),
#  Document(metadata={}, page_content='RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.  \n \nRDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de Vigilância'),
#  Document(metadata={}, page_content='Sanitária (SNVS) destinados à oferta no território nacional.  \n \nIN 281/2024 - Forma de regularização das diferentes categorias de alimentos e embalagens, e a respectiva \ndocumentação que deve ser apresentada.'),
#  Document(metadata={}, page_content='1.2. Procedimentos para avaliação de risco, segurança e eficácia de alimentos  \n \nTema Regulatório 3.8 da Agenda Regulatória 2024/2025: Regulamentação das listas de novos alimentos e'),
#  Document(metadata={}, page_content='novos ingredientes autorizados e suas especificações. \nRES 18/1999 – Análise e comprovação de propriedades funcionais e ou de saúde alegadas em rotulagem de \nalimentos. \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de \nVigilância Sanitária (SNVS) destinados à oferta no território nacional. \nAtos relacionados:'),
#  Document(metadata={}, page_content='RDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos probióticos \npara uso em alimentos.'),
#  Document(metadata={}, page_content='Guia nº 55, versão 1, de 25/11/2021  - Guia para avaliação de alegação de propriedade funcional e de \nsaúde para substâncias bioativas presentes em alimentos e suplementos alimentares.'),
#  Document(metadata={}, page_content='RDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos probióticos para uso \nem alimentos. \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes. \nRDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de'),
#  Document(metadata={}, page_content='Vigilância Sanitária (SNVS) destinados à oferta no território nacional. \nAto relacionado: \nGuia nº 21, versão 2, de 05/05/2021  - Guia para Instrução Processual de Petição de Avaliação de'),
#  Document(metadata={}, page_content='Probióticos para Uso em Alimentos. \nDocumento relacionado: \nPerguntas e Respostas sobre Alteração Taxonômica de Espécies do Gênero Lactobacillus'),
#  Document(metadata={}, page_content='Guia nº 37, versão 1, de 02/09/2020 - Guia de Especificações de Ingredientes Alimentares. \n \nRDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.'),
#  Document(metadata={}, page_content='RDC 868/2024 - Diretrizes básicas para avaliação de risco e segurança dos alimentos.  \nAtos relacionados: \nRDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos probióticos'),
#  Document(metadata={}, page_content='para uso em alimentos. \nGuia nº 23, versão 1, de 23/07/2019  - Guia para Comprovação da Segurança de Alimentos e \nIngredientes. \nDocumento relacionado:'),
#  Document(metadata={}, page_content='Perguntas e Respostas sobre Solicitações Pós -Publicação de Petições de Avaliação da Área de \nAlimentos. \n1.3. Padrões microbiológicos para alimentos'),
#  Document(metadata={}, page_content='Tema Regulatório 3.31 da Agenda Regulatória 2024/2025: Atualização periódica da lista de padrões \nmicrobiológicos para alimentos. \n \n \nRDC 724/2022 - Padrões microbiológicos dos alimentos e sua aplicação.'),
#  Document(metadata={}, page_content='Ato relacionado: \nIN 161/2022 - Padrões microbiológicos dos alimentos. \nDocumento relacionado: \nPerguntas e Respostas sobre Padrões Microbiológicos'),
#  Document(metadata={}, page_content='IN 161/2022 - Padrões microbiológicos dos alimentos. (Atualização Periódica) \nAlterada por: \nIN 313/2024  \n1.4. Irradiação de alimentos \n \nRDC 21/2001 – Regulamento técnico para irradiação de alimentos.'),
#  Document(metadata={}, page_content='1.5. Procedimentos para autorização de uso de aditivos alimentares e coadjuvantes \nde tecnologia  \n \nTema Regulatório 3.5 da Agenda Regulatória 2024/2025: Reavaliação da autorização de uso do aditivo'),
#  Document(metadata={}, page_content='alimentar dióxido de titânio em alimentos. \nTema Regulatório 3.9 da Agenda Regulatória 2024/2025: Regulamentação dos aditivos corantes formulados \ne da rotulagem de corantes e aromatizantes em alimentos embalados.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.14 da Agenda Regulatória 2024/2025: Revisão da regulamentação de aditivos  \nalimentares e coadjuvantes de tecnologia autorizados para uso em produtos lácteos.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.15 da Agenda Regulatória 2024/2025: Revisão da regulamentação de aditivos  \nalimentares e coadjuvantes de tecnologia em alimentos.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.16 da Agenda Regulatória 2024/2025: Revisão da regulamentação de autorização de uso \ne de rotulagem de aditivos edulcorantes em alimentos.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.34 da Agenda Regulatória 2024/2025: Atualização periódica das listas de aditivos  \nalimentares e coadjuvantes de tecnologia autorizados para uso em alimentos.'),
#  Document(metadata={}, page_content='Guia nº 43, versão 1, de 14/12/2020  - Procedimentos para Pedidos de Inclusão e Extensão de Uso de Aditivos \nAlimentares e Coadjuvantes de Tecnologia de Fabricação na Legislação Brasileira.'),
#  Document(metadata={}, page_content='RDC 725/2022 - Aditivos alimentares aromatizantes.   \nDocumento relacionado: \nPerguntas e Respostas sobre Aditivos Aromatizantes de Espécies Botânicas Regionais'),
#  Document(metadata={}, page_content='RDC 728/2022 - Enzimas e as preparações enzimáticas para uso como coadjuvantes de tecnologia na produção \nde alimentos destinados ao consumo humano.'),
#  Document(metadata={}, page_content='RDC 778/2023 - Princípios gerais, as funções tecnológicas e as condições de uso de aditivos alimentares e \ncoadjuvantes de tecnologia em alimentos. \nAlterada por: \n \n \nRDC 826/2023 \nRDC 849/2024'),
#  Document(metadata={}, page_content='Atos relacionados: \nIN 211/2023 \nGuia nº 43, versão 1, de 14/12/2020  - Procedimentos para Pedidos de Inclusão e Extensão de Uso de'),
#  Document(metadata={}, page_content='Aditivos Alimentares e Coadjuvantes de Tecnologia de Fabricação na Legislação Brasileira. \nDocumento relacionado: \nPerguntas e Respostas sobre Aditivos Alimentares e Coadjuvantes de Tecnologia'),
#  Document(metadata={}, page_content='RDC 779/2023 - Aditivos alimentares fermentos químicos e sobre os coadjuvantes de tecnologia fermentos \nbiológicos e nutrientes para levedura destinados ao uso em produtos de panificação e biscoitos.'),
#  Document(metadata={}, page_content='Ato relacionado: \nIN 211/2023 \n \nRDC 818/2023 - Requisitos sanitários dos adoçantes de mesa e dos adoçantes dietéticos. \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de \nVigilância Sanitária (SNVS) destinados à oferta no território nacional.'),
#  Document(metadata={}, page_content='IN 211/2023 - Funções tecnológicas, os limites máximos e as condições de uso para os aditivos alimentares e \nos coadjuvantes de tecnologia autorizados para uso em alimentos. (Atualização Periódica) \nAlterada por:'),
#  Document(metadata={}, page_content='IN 221/2023 \nIN 223/2023 \nIN 267/2023 \nIN 274/2024 \nIN 286/2024 \nIN 295/2024 \nIN 297/2024 \nIN 303/2024 \nIN 306/2024 \n1.6. Contaminantes em alimentos'),
#  Document(metadata={}, page_content='Tema Regulatório 3.17 da Agenda Regulatória 2024/2025: Revisão da regulamentação de contaminantes em \nalimentos.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.32 da Agenda Regulatória 2024/2025: Atualização periódica da lista de limites máximos \ntolerados (LMT) de contaminantes em alimentos. \nRDC 281/2003 – Benzo(a)pireno em alimentos.'),
#  Document(metadata={}, page_content='RDC 722/2022 - Limites máximos tolerados (LMT) de contaminantes em alimentos, os princípios gerais para o \nseu estabelecimento e os métodos de análise para fins de avaliação de conformidade. \nAto relacionado:'),
#  Document(metadata={}, page_content='IN 160/2022 \nDocumento relacionado: \n \n \nDocumento de Perguntas e Respostas sobre Contaminantes em Alimentos.'),
#  Document(metadata={}, page_content='IN 160/2022 - Limites máximos tolerados (LMT) de contaminantes em alimentos. (Atualização Periódica)  \n1.7. Matérias estranhas macroscópicas e microscópicas em alimentos'),
#  Document(metadata={}, page_content='RDC 623/2022 - Limites de tolerância para matérias estranhas em alimentos, os princípios gerais para o seu \nestabelecimento e os métodos de análise para fins de avaliação de conformidade.'),
#  Document(metadata={}, page_content='1.8. Resíduos de medicamentos veterinários em alimentos de origem animal \n \nTema Regulatório 3.33 da Agenda Regulatória 2024/2025: Atualização periódica da lista de LMR, IDA, DRfA'),
#  Document(metadata={}, page_content='para IFA de medicamentos veterinários em alimentos de origem animal. \nRDC 730/2022 - Avaliação do risco à saúde humana de medicamentos veterinários, os limites máximos de'),
#  Document(metadata={}, page_content='resíduos (LMR) de medicamentos veterinários em alimentos de origem animal e os métodos de análise para \nfins de avaliação da conformidade. \nAto relacionado:'),
#  Document(metadata={}, page_content='IN 162/2022 - Ingestão diária aceitável (IDA), a dose de referência aguda (DRfA) e os limites máximos \nde resíduos (LMR) para insumos farmacêuticos ativos (IFA) de medicamentos veterinários em'),
#  Document(metadata={}, page_content='alimentos de origem animal. \nDocumento relacionado:  \nPerguntas e Respostas sobre Limites máximos de resíduos (LMR) de medicamentos veterinários em \nalimentos de origem animal.'),
#  Document(metadata={}, page_content='IN 162/2022  - Ingestão diária aceitável (IDA), a dose de referência aguda (DRfA) e os limites máximos de \nresíduos (LMR) para insumos farmacêuticos ativos (IFA) de medicamentos veterinários em alimentos de'),
#  Document(metadata={}, page_content='origem animal. (Atualização Periódica) \nAlterada por: \nIN 241/2023 \nIN 317/2024 \n1.9. Materiais em contato com alimentos'),
#  Document(metadata={}, page_content='Tema Regulatório 3.7 da Agenda Regulatória 2024/2025: Regulamentação da reciclagem de materiais  \nplásticos em contato com alimentos.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.12 da Agenda Regulatória 2024/2025: Regulamentação dos requisitos sanitários para  \nmateriais de silicone em contato com alimentos - A regulamentar.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.13 da Agenda Regulatória 2024/2025: Revisão da lista positiva de aditivos destinados à  \nelaboração de materiais plásticos e revestimentos poliméricos em contato com alimentos.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.18 da Agenda Regulatória 2024/2025: Revisão da regulamentação de embalagens de  \nPET-PCR grau alimentício destinados a entrar em contato com alimentos.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.19 da Agenda Regulatória 2024/2025: Revisão da regulamentação de materiais  \nmetálicos em contato com alimentos.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.20 da Agenda Regulatória 2024/2025: Revisão da regulamentação de películas de  \ncelulose regeneradas em contato com alimentos.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.21 da Agenda Regulatória 2024/2025: Revisão da regulamentação sobre materiais,  \nembalagens e equipamentos celulósicos destinados a entrar em contato com alimentos.'),
#  Document(metadata={}, page_content='Portaria SVS/MS 27/1996 – Embalagens e equipamentos de vidro e cerâmica destinados a entrar em contato \ncom alimentos. \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de \nVigilância Sanitária (SNVS) destinados à oferta no território nacional.'),
#  Document(metadata={}, page_content='Portaria SVS/MS 987/1998 – Embalagens descartáveis de polietileno tereftalato (PET) destinadas ao \nacondicionamento de bebidas não alcoólicas carbonatadas.'),
#  Document(metadata={}, page_content='RES 105/1999 – Disposições gerais para embalagens e equipamentos plásticos em contato com alimentos. \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 51/2010 – Critérios de migração para materiais, embalagens e equipamentos plásticos destinados \na entrar em contato com alimentos.'),
#  Document(metadata={}, page_content='RDC 52/2010 – Corantes em embalagens e equipamentos plásticos destinados a estar em contato com \nalimentos. \nRDC 56/2012 – Lista positiva de monômeros, outras substâncias iniciadoras e polímeros autorizados'),
#  Document(metadata={}, page_content='para a elaboração de embalagens e equipamentos plásticos em contato com alimentos.  \nRDC 326/2019  - Lista positiva de aditivos destinados à elaboração de materiais plásticos e'),
#  Document(metadata={}, page_content='revestimentos poliméricos em contato com alimentos. \nRDC 589/2021 \nRDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de'),
#  Document(metadata={}, page_content='Vigilância Sanitária (SNVS) destinados à oferta no território nacional.   \n \nRDC 91/2001 – Critérios gerais e classificação de materiais para embalagens em contato com alimentos \nDocumento relacionado:'),
#  Document(metadata={}, page_content='Perguntas e Respostas sobre Materiais em contato com alimentos \n \nRDC 122/2001 – Ceras e parafinas em contato com alimentos. \n \nRDC 123/2001 – Embalagens e equipamentos elastoméricos em contato com alimentos.'),
#  Document(metadata={}, page_content='RDC 124/2001  – Preparados formadores de películas a base de polímeros e/ou resinas destinados ao \nrevestimento de Alimentos.'),
#  Document(metadata={}, page_content='RDC 146/2001  – Processo de deposição de camada interna de carbono amorfo em garrafas de polietileno \ntereftalato (PET). \n \nRDC 217/2002 – Películas de celulose regenerada em contato com alimentos. \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 755/2022 \n \nRDC 218/2002 – Tripas sintéticas de celulose regenerada em contato com Alimentos. \n \n \nRDC 20/2008 – Embalagens de polietileno  tereftalato (PET) pós-consumo reciclado grau alimentício (PET -PCR'),
#  Document(metadata={}, page_content='grau alimentício) destinados a entrar em contato com alimentos. \nAlterada por: \nRDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de'),
#  Document(metadata={}, page_content='Vigilância Sanitária (SNVS) destinados à oferta no território nacional. \n \nRDC 51/2010 – Critérios de migração para materiais, embalagens e equipamentos plásticos destinados a entrar \nem contato com alimentos.'),
#  Document(metadata={}, page_content='RDC 52/2010  – Corantes em embalagens e equipamentos plásticos destinados a estar em contato com \nalimentos. \nAlterada por: \nRDC 326/2019'),
#  Document(metadata={}, page_content='RDC 56/2012 – Lista positiva de monômeros, outras substâncias iniciadoras e polímeros autorizados para a \nelaboração de embalagens e equipamentos plásticos em contato com alimentos.  \nAlterada por:  \nRDC 326/2019'),
#  Document(metadata={}, page_content='RDC 589/2021 \n \nRDC 88/2016  – Materiais, embalagens e equipamentos celulósicos destinados a entrar em contato com \nalimentos. \nAlterada por:  \nRDC 589/2021 \nRDC 798/2023'),
#  Document(metadata={}, page_content='RDC 89/2016 – Materiais celulósicos para cocção e filtração a quente. \n \nRDC 90/2016  – Materiais, embalagens e equipamentos celulósicos destinados a entrar em contato com'),
#  Document(metadata={}, page_content='alimentos durante a cocção ou aquecimento em forno. \n \nRDC 326/2019  - Lista positiva de aditivos destinados à elaboração de materiais plásticos e revestimentos \npoliméricos em contato com alimentos.'),
#  Document(metadata={}, page_content='RDC 854/2024  - Requisitos sanitários aplicáveis às embalagens, revestimentos, utensílios, tampas e \nequipamentos metálicos destinados a entrar em contato com alimentos.  \nAto relacionado:'),
#  Document(metadata={}, page_content='Lei 9.832/1999 – Proibição do uso industrial de embalagens metálicas soldadas com liga de chumbo e \nestanho para acondicionamento de gêneros alimentícios, exceto para produtos secos ou desidratados.'),
#  Document(metadata={}, page_content='1.10. Requisitos Sanitários para enriquecimento e restauração de alimentos \n \nRDC 604/2022 - Enriquecimento obrigatório do sal com iodo e das farinhas de trigo e de milho com ferro e'),
#  Document(metadata={}, page_content='ácido fólico destinados ao consumo humano. \nAlterada por: \nRDC 612/2022 \nDocumento relacionado: \n \n \nPerguntas e Respostas sobre Enriquecimento de Farinhas de Trigo e de Milho com Ferro e Ácido Fólico.'),
#  Document(metadata={}, page_content='RDC 714/2022 - Requisitos sanitários para enriquecimento e restauração de alimentos.  \nAlterada por: \nRDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes.'),
#  Document(metadata={}, page_content='RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.  \n1.11. Requisitos sanitários para alimentos para fins especiais'),
#  Document(metadata={}, page_content='Tema Regulatório 3.27 da Agenda Regulatória 2024/2025: Revisão e consolidação da regulamentação  sobre \nalimentos infantis, fórmulas para nutrição  enteral e fórmulas dietoterápicas para erros  inatos do'),
#  Document(metadata={}, page_content='metabolismo. \nPortaria SVS/MS 34/1998 – Alimentos de transição para lactentes e crianças de primeira infância. \nAlterada por: \nRDC 42/2011 \nRDC 68/2016 \nRDC 429/2020'),
#  Document(metadata={}, page_content='RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de \nVigilância Sanitária (SNVS) destinados à oferta no território nacional.'),
#  Document(metadata={}, page_content='Portaria SVS/MS 36/1998 – Alimentos à base de cereais para alimentação infantil. \nAlterada por: \nRDC 42/2011 – Compostos de nutrientes para alimentos destinados a lactentes e crianças de primeira \ninfância.'),
#  Document(metadata={}, page_content='RDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos probióticos \npara uso em alimentos. \nRDC 429/2020 - Rotulagem nutricional dos alimentos embalados.'),
#  Document(metadata={}, page_content='RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes. \nRDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de'),
#  Document(metadata={}, page_content='Vigilância Sanitária (SNVS) destinados à oferta no território nacional. \n \nRDC 42/2011 – Compostos de nutrientes para alimentos destinados a lactentes e crianças de primeira infância. \nAlterada por: \nRDC 45/2014'),
#  Document(metadata={}, page_content='RDC 43/2011 – Fórmulas infantis para lactentes. \nRDC 44/2011 – Fórmulas infantis de seguimento para lactentes e crianças de primeira infância.'),
#  Document(metadata={}, page_content='RDC 45/2011  – Fórmulas infantis para lactentes destinadas a necessidades dietoterápicas específicas e \nfórmulas infantis de seguimento para lactentes e crianças de primeira infância destinadas a necessidades'),
#  Document(metadata={}, page_content='dietoterápicas específicas. \nAlteradas por: \nRDC 46/2014 – Altera a RDC 43/2011. \nRDC 47/2014 – Altera a RDC 44/2011. \n \n \nRDC 48/2014 – Altera a RDC 45/2011. \nRDC 241/2018 – Altera as RDC´s 43 e 44/2011.'),
#  Document(metadata={}, page_content='RDC 429/2020 – Altera as RDC´s 43, 44, 45/2011. \nRDC 729/2022 - Melhora da técnica legislativa e revogação de normas inferiores a Decreto editadas'),
#  Document(metadata={}, page_content='pela ANVISA, componentes da quinta etapa de consolidação da pertinência temática de alimentos em \nobservância ao que prevê a Portaria nº 488/GADIP -DP/ANVISA, de 23 de setembro de 2021 e o'),
#  Document(metadata={}, page_content='Decreto nº 10.139, de 28 de novembro de 2019. Altera as RDC´s 43, 44, 45/2011. \nRDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes.  \nDocumento relacionado:'),
#  Document(metadata={}, page_content='Perguntas e Respostas sobre Fórmulas Infantis. \n \nRDC 21/2015 – Fórmulas para nutrição enteral. \nRDC 22/2015 – Compostos de nutrientes e de outras substâncias para fórmulas para nutrição enteral. \nAlteradas por:'),
#  Document(metadata={}, page_content='RDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos probióticos \npara uso em alimentos. Altera a RDC 22/2015.'),
#  Document(metadata={}, page_content='RDC 401/2020 - Altera a RDC  22/2015 para atualizar as referências de especificações para  compostos \nfontes de nutrientes e outras substâncias para uso em fórmulas para nutrição enteral.'),
#  Document(metadata={}, page_content='RDC 429/2020 - Rotulagem nutricional dos alimentos embalados. Altera a RDC 21/2015. \nRDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes. Altera a RDC 22/2015.'),
#  Document(metadata={}, page_content='Documento relacionado: \nPerguntas e Respostas sobre Fórmulas para Nutrição Enteral. \n \nRDC 460/2020 - Requisitos sanitários das fórmulas dietoterápicas para erros inatos do metabolismo.  \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 429/2020 - Rotulagem nutricional dos alimentos embalados.  \nRDC 729/2022 - Melhora da técnica legislativa e revogação de normas inferiores a Decreto editadas'),
#  Document(metadata={}, page_content='pela ANVISA, componentes da quinta etapa de consolidação da pertinência temática de alimentos em \nobservância ao que prevê a Portaria nº 488/GADIP -DP/ANVISA, de 23 de setembro de 2021 e o'),
#  Document(metadata={}, page_content='Decreto nº 10.139, de 28 de novembro de 2019. \nRDC 818/2023 - Requisitos sanitários dos adoçantes de mesa e dos adoçantes dietéticos.'),
#  Document(metadata={}, page_content='RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes.  \nRDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de'),
#  Document(metadata={}, page_content='Vigilância Sanitária (SNVS) destinados à oferta no território nacional. \n \nRDC 715/2022 - Requisitos sanitários do sal hipossódico, dos alimentos para controle de peso, dos alimentos'),
#  Document(metadata={}, page_content='para dietas com restrição de nutrientes e dos alimentos para dietas de ingestão controlada de açúcares. \nAlterada por: \nRDC 818/2023 - Requisitos sanitários dos adoçantes de mesa e dos adoçantes dietéticos.'),
#  Document(metadata={}, page_content='RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes.  \n \nRDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.'),
#  Document(metadata={}, page_content='1.12. Requisitos sanitários para suplementos alimentares \n \nTema Regulatório 3.29 da Agenda Regulatória 2024/2025: Atualização periódica da lista de constituintes, de'),
#  Document(metadata={}, page_content='limites de uso, de alegações e de rotulagem complementar dos suplementos alimentares. \nRDC 243/2018 – Requisitos sanitários dos suplementos alimentares. \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 429/2020 - Rotulagem nutricional dos alimentos embalados.  \nRDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes.'),
#  Document(metadata={}, page_content='RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de \nVigilância Sanitária (SNVS) destinados à oferta no território nacional. \nAto relacionado:'),
#  Document(metadata={}, page_content='IN 28/2018 – Listas de constituintes, de limites de uso, de alegações e de rotulagem complementar dos \nsuplementos alimentares. \nDocumentos relacionados: \nPerguntas e Respostas sobre Suplementos Alimentares.'),
#  Document(metadata={}, page_content='Perguntas e Respostas sobre Substâncias Bioativas. \nIN 28/2018  – Listas de constituintes, de limites de uso, de alegações e de rotulagem complementar dos \nsuplementos alimentares. (Atualização Periódica)'),
#  Document(metadata={}, page_content='Alterada por: \nIN 76/2020 – Atualiza as listas de constituintes, de limites de uso, de alegações e de rotulagem \ncomplementar dos suplementos alimentares. \nIN 102/2021 \nIN 275/2024 \nIN 284/2024 \nIN 304/2024'),
#  Document(metadata={}, page_content='IN 318/2024 \n \nRDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.   \n1.13. Requisitos para uso de gordura trans industrial em alimentos'),
#  Document(metadata={}, page_content='RDC 632/2022 - Restrição de uso de gorduras trans industriais em alimentos.  \nDocumento relacionado: \nPerguntas e Respostas – Requisitos para uso de Gorduras Trans Industriais em Alimentos.'),
#  Document(metadata={}, page_content='1.14. Requisitos sanitários para amidos, biscoitos, cereais integrais, cereais \nprocessados, farelos, farinhas, farinhas integrais, massas alimentícias e pães'),
#  Document(metadata={}, page_content='RDC 604/2022 - Enriquecimento obrigatório do sal com iodo e das farinhas de trigo e de milho com ferro e \nácido fólico destinados ao consumo humano. \nAlterada por: \nRDC 612/2022 \nDocumento relacionado:'),
#  Document(metadata={}, page_content='Perguntas e Respostas sobre Enriquecimento de Farinhas de Trigo e de Milho com Ferro e Ácido Fólico \n \nRDC 711/2022  - Requisitos sanitários dos amidos, biscoitos, cereais integrais, cereais processados, farelos,'),
#  Document(metadata={}, page_content='farinhas, farinhas integrais, massas alimentícias e pães.  \n \n \nAlterada por: \nRDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes.'),
#  Document(metadata={}, page_content='RDC 712/2022 - Requisitos de composição e rotulagem dos alimentos contendo cereais e pseudocereais para \nclassificação e identificação como integral e para destaque da presença de ingredientes integrais.'),
#  Document(metadata={}, page_content='Documento relacionado: \nPerguntas e Respostas sobre Cereais Integrais \n \nRDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.'),
#  Document(metadata={}, page_content='1.15. Requisitos sanitários para açúcares, bala, bombom, cacau em pó, cacau \nsolúvel, chocolate, chocolate branco, goma de mascar, manteiga de cacau, \nmassa de cacau, melaço, melado e rapadura'),
#  Document(metadata={}, page_content='RDC 723/2022 - Requisitos sanitários do açúcar, açúcar líquido invertido, açúcar de confeitaria, bala, bombom, \ncacau em pó, cacau solúvel, chocolate, chocolate branco, goma de mascar, manteiga de cacau, massa de'),
#  Document(metadata={}, page_content='cacau, melaço, melado e rapadura. \nAlterada por: \nRDC 818/2023 - Requisitos sanitários dos adoçantes de mesa e dos adoçantes dietéticos.'),
#  Document(metadata={}, page_content='RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes. \n \nRDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.'),
#  Document(metadata={}, page_content='1.16. Requisitos sanitários para g elados comestíveis e preparados para gelados \ncomestíveis \n \nRDC 713/2022 - Requisitos sanitários dos gelados comestíveis e dos preparados para gelados comestíveis.'),
#  Document(metadata={}, page_content='Alterada por: \nRDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes.'),
#  Document(metadata={}, page_content='RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.  \n1.17. Requisitos sanitários para cogumelos, produtos de frutas e produtos de \nvegetais'),
#  Document(metadata={}, page_content='RDC 726/2022 - Requisitos sanitários dos cogumelos comestíveis, dos produtos de frutas e dos produtos de \nvegetais.  \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes. \n \nRDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.'),
#  Document(metadata={}, page_content='1.18. Requisitos sanitários para óleos e gorduras vegetais \n \nTema Regulatório 3.30 da Agenda Regulatória 2024/2025: Atualização periódica da lista de espécies vegetais'),
#  Document(metadata={}, page_content='autorizadas, as designações, a  composição de ácidos graxos e os valores  máximos de acidez e de índice de \nperóxidos para óleos e gorduras vegetais.'),
#  Document(metadata={}, page_content='RDC 481/2021 - Requisitos sanitários para óleos e gorduras vegetais. \n Alterada por: \nRDC 729/2022 - Melhora da técnica legislativa e revogação de normas inferiores a Decreto editadas'),
#  Document(metadata={}, page_content='pela ANVISA, componentes da quinta etapa de consolidação da pertinência temática de alimentos em \nobservância ao que prevê a Portaria nº 488/GADIP -DP/ANVISA, de 23 de setembro de 2021 e o'),
#  Document(metadata={}, page_content='Decreto nº 10.139, de 28 de novembro de 2019. \nRDC 829/2023 \nRDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes. \nAto relacionado:'),
#  Document(metadata={}, page_content='IN 87/2021  - Estabelece a lista de espécies vegetais autorizadas, as designações, a composição de \nácidos graxos e os valores máximos de acidez e de índice de peróxidos para óleos e gorduras vegetais.'),
#  Document(metadata={}, page_content='Documento relacionado: \nPerguntas e Respostas sobre Óleos e Gorduras Vegetais \n \nRDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.'),
#  Document(metadata={}, page_content='IN 87/2021  - Estabelece a lista de espécies vegetais autorizadas, as designações, a composição de ácidos \ngraxos e os valores máximos de acidez e de índice de peróxidos para óleos e gorduras vegetais.'),
#  Document(metadata={}, page_content='Alterada por: \nIN 311/2024 \n1.19. Requisitos sanitários para palmito em conserva \n \nRDC 18/1999 - Processo de industrialização e comercialização de palmitos. \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 7/2000 – Certificado de Boas Práticas de Fabricação e controle para fins de autorização para \nexportação de palmito em conserva para o Brasil.'),
#  Document(metadata={}, page_content='RDC 81/2003  – Obrigatoriedade de identificação do fabricante do produto palmito em conserva, \nlitografada na parte lateral da tampa metálica da embalagem de vidro do produto palmito em'),
#  Document(metadata={}, page_content='conserva e elaboração, implementação e manutenção de Procedimentos Operacionais Padronizados – \nPOPs para acidificação e tratamento térmico.'),
#  Document(metadata={}, page_content='RDC 729/2022 - Melhora da técnica legislativa e revogação de normas inferiores a Decreto editadas \npela ANVISA, componentes da quinta etapa de consolidação da pertinência temática de alimentos em'),
#  Document(metadata={}, page_content='observância ao que prevê a Portaria nº 488/GADIP -DP/ANVISA, de 23 de setembro de 2021 e o \nDecreto nº 10.139, de 28 de novembro de 2019.'),
#  Document(metadata={}, page_content='RDC 726/2022 - Requisitos sanitários dos cogumelos comestíveis, dos produtos de frutas e dos produtos de \nvegetais.  \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes. \n \nRDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.'),
#  Document(metadata={}, page_content='1.20. Requisitos sanitários para misturas para o preparo de alimentos e alimentos \nprontos para consumo'),
#  Document(metadata={}, page_content='RDC 719/2022 - Requisitos sanitários das misturas para o preparo de alimentos e dos alimentos prontos para o \nconsumo. \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes. \n \nRDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.'),
#  Document(metadata={}, page_content='1.21. Requisitos sanitários para águas envasadas e gelo destinados ao consumo \nhumano  \n \nDecreto-Lei nº 7.841/1945 – Código de águas minerais.'),
#  Document(metadata={}, page_content='RDC 717/2022 - Requisitos sanitários das águas envasadas e do gelo para consumo humano. \nAto relacionado: \nPortaria de Consolidação GM/MS 5/2017 \nAlterada por:  \nPortaria MS 2472/2021'),
#  Document(metadata={}, page_content='1.22. Requisitos sanitários para café, cevada, chás, erva-mate, especiarias, temperos \ne molhos \n \nTema Regulatório 3.28 da Agenda Regulatória 2024/2025: Atualização periódica da lista das partes de'),
#  Document(metadata={}, page_content='vegetais autorizadas para o preparo de chás e para uso como especiarias. \nRDC 716/2022 - Requisitos sanitários do café, cevada, chás, erva-mate, especiarias, temperos e molhos. \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes. \n \nIN 159/2022 - Listas das partes de espécies vegetais autorizadas para o preparo de chás e para o uso como'),
#  Document(metadata={}, page_content='especiarias. (Atualização Periódica)   \nAlterada por: \nIN 197/2022 \nIN 262/2023 \nIN 273/2024 \n \nRDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.'),
#  Document(metadata={}, page_content='1.23. Requisitos sanitários para sal destinado ao consumo humano \n \nLei 6.150/1974 – Dispõe sobre a obrigatoriedade da iodação do sal, destinado ao consumo humano, seu'),
#  Document(metadata={}, page_content='controle pelos órgãos sanitários e dá outras providências \nDecreto 75.697/1975 – Padrões de identidade e qualidade para o sal destinado ao consumo humano.'),
#  Document(metadata={}, page_content='RDC 604/2022 - Enriquecimento obrigatório do sal com iodo e das farinhas de trigo e de milho com ferro e \nácido fólico destinados ao consumo humano. \nAlterada por: \nRDC 612/2022'),
#  Document(metadata={}, page_content='1.24. Requisitos Sanitários dos alimentos nutricionalmente modificados \n \nRDC 720/2022 - Requisitos sanitários dos alimentos nutricionalmente modificados.  \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos \ningredientes. \nDocumento relacionado:'),
#  Document(metadata={}, page_content='Perguntas e respostas sobre modificações na composição de alimentos padronizados para alegações \nnutricionais.'),
#  Document(metadata={}, page_content='RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.  \n1.25. Admissibilidade de análise realizada por Autoridade Reguladora Estrangeira \nEquivalente (AREE)'),
#  Document(metadata={}, page_content='Tema Regulatório 3.1 da Agenda Regulatória 2024/2025 - A regulamentar. \n1.26. Regulamentação dos alimentos para fins médicos \n \nTema Regulatório 3.10 da Agenda Regulatória 2024/2025 - A regulamentar.'),
#  Document(metadata={}, page_content='1.27. Regulamentação dos alimentos plant-based \n \nTema Regulatório 3.11 da Agenda Regulatória 2024/2025 - A regulamentar. \n2. Informações ao consumidor \n2.1. Rotulagem de Alimentos'),
#  Document(metadata={}, page_content='Tema Regulatório 3.3 da Agenda Regulatória 2024/2025: Identificação de estratégias para promover o  \nacesso a informações necessárias ao consumo seguro de alimentos por pessoas com deficiência visual.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.6 da Agenda Regulatória 2024/2025: Regulamentação da declaração quantitativa de  \ningredientes na rotulagem de alimentos embalados.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.9 da Agenda Regulatória 2024/2025: Regulamentação dos aditivos corantes formulados \ne da rotulagem de corantes e aromatizantes em alimentos embalados.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.16 da Agenda Regulatória 2024/2025: Revisão da regulamentação de autorização de uso \ne de rotulagem de aditivos edulcorantes em alimentos.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.23 da Agenda Regulatória 2024/2025: Revisão da regulamentação sobre rotulagem  dos \nprincipais alimentos alergênicos.'),
#  Document(metadata={}, page_content='Tema Regulatório 3.24 da Agenda Regulatória 2024/2025: Revisão da regulamentação sobre rotulagem geral \nde alimentos embalados.'),
#  Document(metadata={}, page_content='Tema 3.25 da Agenda Regulatória 2024/2025: Revisão da regulamentação sobre rotulagem  nutricional dos \nalimentos embalados. \nDecreto-Lei 986/1969 – Institui normas básicas sobre alimentos. \nAlterado por:'),
#  Document(metadata={}, page_content='Lei 13.305/2016 – Altera Decreto-Lei 986/1969 para dispor sobre rotulagem de alimentos com lactose. \n \nDecreto 4.680/2003 – Regulamenta o direito à informação  quanto aos alimentos e ingredientes alimentares'),
#  Document(metadata={}, page_content='destinados ao consumo humano ou animal que contenham ou sejam produzidos a partir de organismos \ngeneticamente modificados. \n Ato relacionado:'),
#  Document(metadata={}, page_content='Portaria MJ 2.658/2003 – Define o símbolo de que trata o art. 2º, § 1º, do Decreto 4.680, de 24 de abril \nde 2003.'),
#  Document(metadata={}, page_content='Lei 10.674/2003  – Obriga a que os produtos alimentícios comercializados informem sobre a presença de \nglúten, como medida preventiva e de controle da doença celíaca.'),
#  Document(metadata={}, page_content='Lei 11.265/2006 – Regulamenta a comercialização de alimentos para lactentes e crianças de primeira infância \ne a de produtos de puericultura correlatos. \n Alterada por:'),
#  Document(metadata={}, page_content='Lei 11.474/2007  – Altera a Lei no 10.188, de 12 de fevereiro de 2001, que cria o Programa de \nArrendamento Residencial, institui o arrendamento residencial com opção de compra, e a Lei no'),
#  Document(metadata={}, page_content='11.265, de 3 de janeiro de 2006, que regulamenta a comercialização de alimentos para lactentes e \ncrianças de primeira infância e a de produtos de puericultura correlatos, e dá outras providências.'),
#  Document(metadata={}, page_content='Ato relacionado: \nDecreto 9.579/2018 – Consolida atos normativos editados pelo Poder Executivo federal que dispõem'),
#  Document(metadata={}, page_content='sobre a temática do lactente, da criança e do adolescente e do aprendiz, e sobre o Conselho Nacional \ndos Direitos da Criança e do Adolescente, o Fundo Nacional para a Criança e o Adolescente e os'),
#  Document(metadata={}, page_content="programas federais da criança e do adolescente. \n \nINC 9/2002 – Embalagens destinadas ao acondicionamento de produtos hortícolas ''in natura''. \n \nRDC 21/2001 – Regulamento técnico para irradiação de alimentos."),
#  Document(metadata={}, page_content='RDC 429/2020 - Rotulagem nutricional dos alimentos embalados.   \nAlterada por: \nRDC 460/2020 - Requisitos sanitários das fórmulas dietoterápicas para erros inatos do metabolismo.'),
#  Document(metadata={}, page_content='RDC 729/2022 - Melhora da técnica legislativa e revogação de normas inferiores a Decreto editadas \npela ANVISA, componentes da quinta etapa de consolidação da pertinência temática de alimentos em'),
#  Document(metadata={}, page_content='observância ao que prevê a Portaria nº 488/GADIP -DP/ANVISA, de 23 de setembro de 2021 e o \nDecreto nº 10.139, de 28 de novembro de 2019. \n \n \nRDC 819/2023 \nAto relacionado:'),
#  Document(metadata={}, page_content='IN 75/2020 - Estabelece os requisitos técnicos para declaração da rotulagem nutricional nos alimentos \nembalados.   \nDocumentos relacionados:'),
#  Document(metadata={}, page_content='Perguntas e Respostas sobre Rotulagem Nutricional de Alimentos embalados  \nPerguntas e Respostas sobre Alegações Nutricionais'),
#  Document(metadata={}, page_content='IN 75/2020  - Estabelece os requisitos técnicos para declaração da rotulagem nutricional nos alimentos \nembalados.   \nAlterada por:'),
#  Document(metadata={}, page_content='RDC 460/2020 - Requisitos sanitários das fórmulas dietoterápicas para erros inatos do metabolismo. \n \nRDC 727/2022 - Rotulagem dos alimentos embalados.  \nAtos relacionados:'),
#  Document(metadata={}, page_content='Lei 12.849/2013 – Obrigatoriedade de as fábricas de produtos que contenham látex natural gravarem \nem suas embalagens advertência sobre a presença dessa substância.'),
#  Document(metadata={}, page_content='RDC 902/2024  - Inclusão de declaração sobre nova fórmula na rotulagem de produtos sujeitos à \nvigilância sanitária quando da alteração de sua composição.'),
#  Document(metadata={}, page_content='Guia nº 5, versão 2, de 16/10/2018 - Guia sobre Programa de Controle de Alergênicos. \nGuia nº 16, versão 1, de 05/10/2018 - Guia para Determinação de Prazos de Validade de Alimentos. \n Documentos relacionados:'),
#  Document(metadata={}, page_content='Perguntas e respostas sobre rotulagem de alimentos alergênicos \nPerguntas e respostas sobre rotulagem de lactose \nPerguntas e Respostas sobre Rotulagem de Nova Fórmula'),
#  Document(metadata={}, page_content='RDC 902/2024 - Inclusão de declaração sobre nova fórmula na rotulagem de produtos sujeitos à vigilância \nsanitária quando da alteração de sua composição. \nDocumento relacionado:'),
#  Document(metadata={}, page_content='Perguntas e Respostas sobre Rotulagem de Nova Fórmula. \n2.2. Informações sobre fenilalanina em alimentos'),
#  Document(metadata={}, page_content='RDC 617/2022 - Obrigatoriedade da realização de análises laboratoriais e da transmissão de informações sobre \nos teores de fenilalanina, proteínas e umidade em alimentos industrializados. \nDocumento relacionado:'),
#  Document(metadata={}, page_content='Perguntas e Respostas sobre Análise de Fenilalanina em Alimentos  \n2.3. Promoção comercial e publicidade em alimentos \n \nDecreto-Lei 986/1969 – Institui normas básicas sobre alimentos.'),
#  Document(metadata={}, page_content='Lei 11.265/2006 – Regulamenta a comercialização de alimentos para lactentes e crianças de primeira infância \ne também a de produtos de puericultura correlatos. \n Alterada por: \nLei 11.474/2007 \nAto relacionado:'),
#  Document(metadata={}, page_content='Decreto 9.579/2018 – Consolida atos normativos editados pelo Poder Executivo federal que dispõem \nsobre a temática do lactente, da criança e do adolescente e do aprendiz, e sobre o Conselho Nacional'),
#  Document(metadata={}, page_content='dos Direitos da Criança e do Adolescente, o Fundo Nacional para a Criança e o Adolescente e os \nprogramas federais da criança e do adolescente.'),
#  Document(metadata={}, page_content='RDC 24/2010 – Dispõe sobre a oferta, propaganda, publicidade, informação e outras práticas correlatas cujo \nobjetivo seja a divulgação e a promoção comercial de alimentos considerados com quantidades elevadas de'),
#  Document(metadata={}, page_content='açúcar, de gordura saturada, de gordura trans, de sódio, e de bebidas com baixo teor nutricional.  \n \nRDC 908/2024 - Requisitos sanitários dos bicos, chupetas e mamadeiras.'),
#  Document(metadata={}, page_content='3. Regularização de serviços e estabelecimentos sujeitos à vigilância sanitária \ne Boas Práticas  \n3.1. Boas Práticas de Fabricação (BPF) para estabelecimentos industrializadores de \nalimentos'),
#  Document(metadata={}, page_content='Tema Regulatório 3.26 da Agenda Regulatória 202 4/2025: Revisão das normas de Boas práticas de  \nfabricação (BPF) para estabelecimentos industrializadores de alimentos.'),
#  Document(metadata={}, page_content='Portaria MS 1.428/1993 – Regulamento técnico para inspeção sanitária de alimentos. \nRDC 275/2002  – Regulamento técnico de procedimentos operacionais padronizados aplicados aos'),
#  Document(metadata={}, page_content='estabelecimentos produtores/industrializadores de alimentos e a lista de verificação das boas práticas de \nfabricação em estabelecimentos produtores/industrializadores de alimentos.'),
#  Document(metadata={}, page_content='RDC 49/2013  – Dispõe sobre a regularização para o exercício de atividade de interesse sanitário do  \nmicroempreendedor individual, do empreendimento familiar rural e do empreendimento econômico solidário'),
#  Document(metadata={}, page_content='Portaria SVS/MS 326/1997 – Regulamento técnico sobre as condições higiênico-sanitárias e de boas práticas \nde fabricação para estabelecimentos produtores/industrializadores de alimentos. \n Ato relacionado:'),
#  Document(metadata={}, page_content='Portaria MAA 360/1997  – Regulamento técnico sobre as condições higiênico -sanitárias e de boas \npráticas de fabricação para estabelecimentos elaboradores/industrializadores de alimentos'),
#  Document(metadata={}, page_content='RDC 18/1999 - Processo de industrialização e comercialização de palmitos. \nAlterada por: \nRDC 7/2000 – Certificado de Boas Práticas de Fabricação e controle para fins de autorização para'),
#  Document(metadata={}, page_content='exportação de palmito em conserva para o Brasil. \nRDC 81/2003  – Obrigatoriedade de identificação do fabricante do produto palmito em conserva,'),
#  Document(metadata={}, page_content='litografada na parte lateral da tampa metálica da embalagem de vidro do produto palmito em \nconserva e elaboração, implementação e manutenção de Procedimentos Operacionais Padronizados –'),
#  Document(metadata={}, page_content='POPs para acidificação e tratamento térmico. \nRDC 729/2022 - Melhora da técnica legislativa e revogação de normas inferiores a Decreto editadas'),
#  Document(metadata={}, page_content='pela ANVISA, componentes da quinta etapa de consolidação da pertinência temática de alimentos em \nobservância ao que prevê a Portaria nº 488/GADIP -DP/ANVISA, de 23 de setembro de 2021 e o'),
#  Document(metadata={}, page_content='Decreto nº 10.139, de 28 de novembro de 2019. \n \nRDC 352/2002 – Boas Práticas de Fabricação para estabelecimentos produtores/industrializadores de frutas e \nou hortaliças em conserva.'),
#  Document(metadata={}, page_content='RDC 172/2003  – Boas Práticas de F abricação para estabelecimentos industrializadores de amendoins  \nprocessados e derivados'),
#  Document(metadata={}, page_content='RDC 267/2003 – Boas Práticas de Fabricação para Estabelecimentos Industrializadores de Gelados Comestíveis. \nRDC 218/2005 – Procedimentos higiênico-sanitários para manipulação de alimentos e bebidas preparados com'),
#  Document(metadata={}, page_content='vegetais. \nRDC 173/2006  – Boas práticas para industrialização e comercialização de água mineral natural e de água \nnatural.'),
#  Document(metadata={}, page_content='RDC 182/2017 – Boas práticas para industrialização, distribuição e comercialização de água adicionada de sais.'),
#  Document(metadata={}, page_content='RDC 28/2000 – Boas Práticas de Fabricação em estabelecimentos beneficiadores de sal destinado ao consumo \nhumano.'),
#  Document(metadata={}, page_content='IN 82/2020 - Boas Práticas de Fabricação de fórmulas dietoterápicas para erros inatos do metabolismo. \nAlterada por:  \nRDC 666/2022 \n3.2. Boas Práticas para Serviços de Alimentação'),
#  Document(metadata={}, page_content='Tema Regulatório 3.2 da Agenda Regulatória 2024/2025. \nRDC 216/2004 – Regulamento técnico de boas práticas para serviços de alimentação. \n Alterada por: \nRDC 52/2014 \nAto relacionado:'),
#  Document(metadata={}, page_content='RDC 49/2013 – Dispõe sobre a regularização para o exercício de atividade de interesse sanitário do \nmicroempreendedor individual, do empreendimento familiar rural e do empreendimento econômico \nsolidário.'),
#  Document(metadata={}, page_content='Documento relacionado: \nCartilha – boas práticas para serviços de alimentação \nRDC 656/2022 - Prestação de serviços de alimentação em eventos de massa.'),
#  Document(metadata={}, page_content='3.3. Conservação nas fases de transporte, comercialização e consumo dos \nalimentos perecíveis, industrializados ou beneficiados, acondicionados em \nembalagens. \n \nResolução CISA/MA/MS nº 10, de 31/07/1984'),
#  Document(metadata={}, page_content='Documento relacionado: \n Perguntas e respostas sobre conservação de alimentos \n3.4. Boas práticas nutricionais \n \nGuia de boas práticas nutricionais – documento de referência'),
#  Document(metadata={}, page_content='Guia de boas práticas nutricionais para pão francês \nGuia de boas práticas nutricionais para restaurantes coletivos \n \n \n3.5. Regularização da doação de alimentos com segurança sanitária'),
#  Document(metadata={}, page_content='Lei 14.016/2020 - Dispõe sobre o combate ao desperdício de alimentos e a doação de excedentes de alimentos \npara o consumo humano.'),
#  Document(metadata={}, page_content='Guia nº 26, versão 2, de 08/01/2021 - Guia de Boas Práticas para Bancos de Alimentos. \n \nGuia nº 57, versão 1, de 07/11/2022 - Guia para Doação de Alimentos com Segurança Sanitária.'),
#  Document(metadata={}, page_content='4. Controle, fiscalização e monitoramento de produtos e serviços  \nLei nº 6.437/1977  – Configura infrações à legislação sanitária federal, estabelece as sanções respectivas, e dá \noutras providências.'),
#  Document(metadata={}, page_content='4.1. Controle, fiscalização e monitoramento de alimentos \n \nLei nº 9.677/1998 – Altera dispositivos do Capítulo III do Título VIII do Código Penal, incluindo na classificação dos'),
#  Document(metadata={}, page_content='delitos considerados hediondos crimes contra a saúde pública, e dá outras providências. \nRE 1/2002  – Proibição da presença de etanol em todos os produtos fortificantes, estimulantes de apetite e'),
#  Document(metadata={}, page_content='crescimento, e complementos de ferro. \nAlterada por:  \nRDC 770/2022 \n \nRE 5052/2011 – Proibir a importação, a fabricação, a distribuição e a comercialização, em todo território nacional,'),
#  Document(metadata={}, page_content='de alimentos e bebidas à base de Aloe Vera. \nRDC 635/2022 - Proibição, em todo o território nacional, da produção, importação, comercialização, propaganda'),
#  Document(metadata={}, page_content='e distribuição de alimentos com forma de apresentação semelhante a cigarro, charuto, cigarrilha, ou qualquer \noutro produto fumígeno, derivado do tabaco ou não.'),
#  Document(metadata={}, page_content='4.2. Programa de controle de alergênicos em alimentos  \n \nRDC 727/2022 - Rotulagem dos alimentos embalados.  \nAtos relacionados:'),
#  Document(metadata={}, page_content='Lei 12.849/2013 – Obrigatoriedade de as fábricas de produtos que contenham látex natural gravarem \nem suas embalagens advertência sobre a presença dessa substância.'),
#  Document(metadata={}, page_content='RDC 902/2024  - Inclusão de declaração sobre nova fórmula na rotulagem de produtos sujeitos à \nvigilância sanitária quando da alteração de sua composição.'),
#  Document(metadata={}, page_content='Guia nº 5, versão 2, de 16/10/2018 - Guia sobre Programa de Controle de Alergênicos. \nGuia nº 16, versão 1, de 05/10/2018 - Guia para Determinação de Prazos de Validade de Alimentos. \n Documentos relacionados:'),
#  Document(metadata={}, page_content='Perguntas e respostas sobre rotulagem de alimentos alergênicos \nPerguntas e respostas sobre rotulagem de lactose \nPerguntas e Respostas sobre Rotulagem de Nova Fórmula \n4.3. Recolhimento de alimentos'),
#  Document(metadata={}, page_content='RDC 655/2022 - Recolhimento de alimentos e sua comunicação à Anvisa e aos consumidores.  \n \n \n4.4. Nutrivigilância \n \nTema Regulatório 3.4 da Agenda Regulatória 2024/2025 - A regulamentar.'),
#  Document(metadata={}, page_content='5. Controle sanitário em comércio exterior e ambientes de portos, aeroportos, \nfronteiras e recintos alfandegados \nRDC 81/2008 - Regulamento técnico de bens e produtos importados para fins de Vigilância Sanitária'),
#  Document(metadata={}, page_content='RDC 172/2017 - Procedimentos para a importação e a exportação de bens e produtos destinados à pesquisa \ncientífica ou tecnológica e à pesquisa envolvendo seres humanos.'),
#  Document(metadata={}, page_content='5.1. Procedimentos para importação de alimentos \n \nRDC 281/2003 – Exigir como procedimento de importação para “aceite de orujo de oliva” ou óleo de bagaço e'),
#  Document(metadata={}, page_content='ou caroço de oliva, sem prejuízo da documentação exigida para este fim, a apresentação do laudo de análise \ndo produto quanto à presença de hidrocarbonetos policíclicos aromáticos, especificamente o alfa -'),
#  Document(metadata={}, page_content='benzopireno, com identificação do lote e ou data de produção ou fabricação. \n \nRE 5052/2011  – Proibir a importação, a fabricação, a distribuição e a comercialização, em todo território'),
#  Document(metadata={}, page_content='nacional, de alimentos e bebidas à base de Aloe Vera \nRDC 635/2022  - Proibição, em todo o território nacional, da produção, importação, comercialização,'),
#  Document(metadata={}, page_content='propaganda e distribuição de alimentos com forma de apresentação semelhante a cigarro, charuto, cigarrilha, \nou qualquer outro produto fumígeno, derivado do tabaco ou não.'),
#  Document(metadata={}, page_content='RDC 722/2022 - Limites máximos tolerados (LMT) de contaminantes em alimentos, os princípios gerais para o \nseu estabelecimento e os métodos de análise para fins de avaliação de conformidade.'),
#  Document(metadata={}, page_content='RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de Vigilância \nSanitária (SNVS) destinados à oferta no território nacional.'),
#  Document(metadata={}, page_content='5.2. Certidão de Venda Livre para Exportação de Alimentos (CVLEA) \n \nRDC 603/2022  - Procedimentos para emissão da Certidão de Venda Livre para Exportação de Alimentos'),
#  Document(metadata={}, page_content='(CVLEA), no âmbito do Sistema Nacional de Vigilância Sanitária.')]

# %% [markdown]
# ## Guardado de los Chunks

# %%
import os

# Create the new folder if it doesn't exist
os.makedirs("Chunks_1", exist_ok=True)

# Split the text into chunks
chunks = text_splitter.split_text(texto_pdf)

# Save each chunk into an individual .txt file
for i, chunk in enumerate(chunks):
    chunk_filename = f"Chunks_1/chunk_{i+1}.txt"
    with open(chunk_filename, "w", encoding="utf-8") as chunk_file:
        chunk_file.write(chunk)

print(f"Saved {len(chunks)} chunks into the 'Chunks_1' folder.")
# Out:
# Saved 269 chunks into the 'Chunks_1' folder.

# %% [markdown]
# ## Semantic Chunking

# %% [markdown]
# ### División de texto en oraciones

# %%
import re

# Splitting the essay on '.', '?', and '!'
single_sentences_list = re.split(r'(?<=[.?!])\s+', texto_pdf)
print (f"{len(single_sentences_list)} sentences were found")
# Out:
# 328 sentences were found

# %%
sentences = [{'sentence': x, 'index' : i} for i, x in enumerate(single_sentences_list)]
#sentences[:10]

# %%
def combine_sentences(sentences, buffer_size=1):
    # Go through each sentence dict
    for i in range(len(sentences)):

        # Create a string that will hold the sentences which are joined
        combined_sentence = ''

        # Add sentences before the current one, based on the buffer size.
        for j in range(i - buffer_size, i):
            # Check if the index j is not negative (to avoid index out of range like on the first one)
            if j >= 0:
                # Add the sentence at index j to the combined_sentence string
                combined_sentence += sentences[j]['sentence'] + ' '

        # Add the current sentence
        combined_sentence += sentences[i]['sentence']

        # Add sentences after the current one, based on the buffer size
        for j in range(i + 1, i + 1 + buffer_size):
            # Check if the index j is within the range of the sentences list
            if j < len(sentences):
                # Add the sentence at index j to the combined_sentence string
                combined_sentence += ' ' + sentences[j]['sentence']

        # Then add the whole thing to your dict
        # Store the combined sentence in the current sentence dict
        sentences[i]['combined_sentence'] = combined_sentence

    return sentences

sentences = combine_sentences(sentences)

# %%
from langchain.embeddings import OpenAIEmbeddings
oaiembeds = OpenAIEmbeddings()

# %%
embeddings = oaiembeds.embed_documents([x['combined_sentence'] for x in sentences])

# %%
for i, sentence in enumerate(sentences):
    sentence['combined_sentence_embedding'] = embeddings[i]

# %%
from sklearn.metrics.pairwise import cosine_similarity

def calculate_cosine_distances(sentences):
    distances = []
    for i in range(len(sentences) - 1):
        embedding_current = sentences[i]['combined_sentence_embedding']
        embedding_next = sentences[i + 1]['combined_sentence_embedding']
        
        # Calculate cosine similarity
        similarity = cosine_similarity([embedding_current], [embedding_next])[0][0]
        
        # Convert to cosine distance
        distance = 1 - similarity

        # Append cosine distance to the list
        distances.append(distance)

        # Store distance in the dictionary
        sentences[i]['distance_to_next'] = distance

    # Optionally handle the last sentence
    # sentences[-1]['distance_to_next'] = None  # or a default value

    return distances, sentences

# %%
distances, sentences = calculate_cosine_distances(sentences)

# %%
#distances[:3]

# %%
import matplotlib.pyplot as plt

plt.plot(distances);

plt.title("Cosine Distance Between Sequential Sentences")
plt.xlabel("Index of sentences in document (Sentence Position)")
plt.ylabel("Cosine distance")
plt.show()

# %%
import numpy as np

plt.plot(distances);

y_upper_bound = .14
plt.ylim(0, y_upper_bound)
plt.xlim(0, len(distances))

# We need to get the distance threshold that we'll consider an outlier
# We'll use numpy .percentile() for this

breakpoint_percentile_threshold = 60
breakpoint_distance_threshold = np.percentile(distances, breakpoint_percentile_threshold) # If you want more chunks, lower the percentile cutoff
plt.axhline(y=breakpoint_distance_threshold, color='r', linestyle='-');

# Then we'll see how many distances are actually above this one
num_distances_above_theshold = len([x for x in distances if x > breakpoint_distance_threshold]) # The amount of distances above your threshold
plt.text(x=(len(distances)*.01), y=y_upper_bound/50, s=f"{num_distances_above_theshold + 1} Chunks");

# Then we'll get the index of the distances that are above the threshold. This will tell us where we should split our text
indices_above_thresh = [i for i, x in enumerate(distances) if x > breakpoint_distance_threshold] # The indices of those breakpoints on your list

# Start of the shading and text
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
for i, breakpoint_index in enumerate(indices_above_thresh):
    start_index = 0 if i == 0 else indices_above_thresh[i - 1]
    end_index = breakpoint_index if i < len(indices_above_thresh) - 1 else len(distances)

    plt.axvspan(start_index, end_index, facecolor=colors[i % len(colors)], alpha=0.25)
    plt.text(x=np.average([start_index, end_index]),
             y=breakpoint_distance_threshold + (y_upper_bound)/ 20,
             s=f"Chunk #{i}", horizontalalignment='center',
             rotation='vertical')

# # Additional step to shade from the last breakpoint to the end of the dataset
if indices_above_thresh:
    last_breakpoint = indices_above_thresh[-1]
    if last_breakpoint < len(distances):
        plt.axvspan(last_breakpoint, len(distances), facecolor=colors[len(indices_above_thresh) % len(colors)], alpha=0.25)
        plt.text(x=np.average([last_breakpoint, len(distances)]),
                 y=breakpoint_distance_threshold + (y_upper_bound)/ 20,
                 s=f"Chunk #{i+1}",
                 rotation='vertical')

plt.title("Chunks Based On Embedding Breakpoints")
plt.xlabel("Index of sentences in document (Sentence Position)")
plt.ylabel("Cosine distance between sequential sentences")
plt.show()

# %%
# Initialize the start index
start_index = 0

# Create a list to hold the grouped sentences
chunks = []

# Iterate through the breakpoints to slice the sentences
for index in indices_above_thresh:
    # The end index is the current breakpoint
    end_index = index

    # Slice the sentence_dicts from the current start index to the end index
    group = sentences[start_index:end_index + 1]
    combined_text = ' '.join([d['sentence'] for d in group])
    chunks.append(combined_text)
    
    # Update the start index for the next group
    start_index = index + 1

# The last group, if any sentences remain
if start_index < len(sentences):
    combined_text = ' '.join([d['sentence'] for d in sentences[start_index:]])
    chunks.append(combined_text)

# grouped_sentences now contains the chunked sentences

# %%
for i, chunk in enumerate(chunks[:100]):
    buffer = 200
    
    print (f"Chunk #{i}")
    print (chunk[:buffer].strip())
    print ("...")
    print (chunk[-buffer:].strip())
    print ("\n")
# Out:
# Chunk #0
# BIBLIOTECA DE
# ALIMENTOS
# Atualizada em 06.11.2024
# Coordenação de Processos Regulatórios – CPROR
# Assessoria de Melhoria da Qualidade Regulatória – ASREG
# Gabinete do Diretor-Presidente
# ...
# otema, divididos por temas. O objetivo é facilitar o acesso e a compreensão do Estoque
# Regulatório ao público interno e externo, bem como aprimorar o processo de elaboração e
# revisão das normativas.
#
#
# Chunk #1
# Não deixe de consultar também a Biblioteca de Temas Transversais, que abrange assuntos
# aplicados a todos os macrotemas, tais como: Autorização de Funcionamento de Empresa
# (AFE), Certificação de Boas
# ...
# dena, supervisiona e controla as atividades de registro, inspeção,
# fiscalização e controle de riscos, sendo responsável por estabelecer normas e padrões de qualidade e
# identidade a serem observados.
#
#
# Chunk #2
# O objetivo é garantir a segurança e a qualidade de alimentos, incluindo bebidas, águas envasadas,
# ingredientes, matérias-primas, aditivos alimentares e coadjuvantes de tecnologia, materiais em contat
# ...
# imentares e coadjuvantes de tecnologia, materiais em contato
# com alimentos, contaminantes, resíduos de medicamentos veterinários, rotulagem e inovações
# tecnológicas em produtos da área de alimentos.
#
#
# Chunk #3
# 1.
# ...
# 1.
#
#
# Chunk #4
# Regularização, avaliação de risco e padrões de alimentos
# Lei 9.782/1999 – Define o Sistema Nacional de Vigilância Sanitária, cria a Agência Nacional de Vigilância
# Sanitária, e dá outras providências
# ...
# 50/2013
# Atos relacionados:
# RDC 470/2021 - Procedimentos para o recebimento de documentos em suporte eletrônico. IN 50/2019 - Lista de assuntos de petição a serem protocoladas em suporte eletrônico.
#
#
# Chunk #5
# Alterada por:
# RDC 472/2021
#
# RDC 702/2022 - Revoga Resoluções de Diretoria Colegiada - RDC, em virtude da publicação da Portaria GM/MS
# nº 913, de 22 de abril de 2022, do Ministro de Estado da Saúde
# ...
# e 2022, do Ministro de Estado da Saúde, que declara o encerramento da Emergência
# em Saúde Pública de Importância Nacional (ESPIN) em decorrência da infecção humana pelo novo coronavírus
# (2019-nCoV).
#
#
# Chunk #6
# 1.1.
# ...
# 1.1.
#
#
# Chunk #7
# Procedimentos para regularização de alimentos
#
# Tema Regulatório 3.22 da Agenda Regulatória 2024/2025: Revisão da regulamentação sobre regularização
# de alimentos dispensados de registro. RDC 20/200
# ...
# os dispensados de registro. RDC 20/2008 - Embalagens de polietileno  tereftalato (PET) pós-consumo reciclado grau alimentício (PET -PCR
# grau alimentício) destinados a entrar em contato com alimentos.
#
#
# Chunk #8
# Alterada por:
# RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de
# Vigilância Sanitária (SNVS) destinados à oferta no território nacional.
# ...
# Alterada por:
# RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de
# Vigilância Sanitária (SNVS) destinados à oferta no território nacional.
#
#
# Chunk #9
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes. RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de Vigi
# ...
# ária (SNVS) destinados à oferta no território nacional. IN 281/2024 - Forma de regularização das diferentes categorias de alimentos e embalagens, e a respectiva
# documentação que deve ser apresentada.
#
#
# Chunk #10
# 1.2. Procedimentos para avaliação de risco, segurança e eficácia de alimentos
#
# Tema Regulatório 3.8 da Agenda Regulatória 2024/2025: Regulamentação das listas de novos alimentos e
# novos ingredien
# ...
# as listas de novos alimentos e
# novos ingredientes autorizados e suas especificações. RES 18/1999 – Análise e comprovação de propriedades funcionais e ou de saúde alegadas em rotulagem de
# alimentos.
#
#
# Chunk #11
# Alterada por:
# RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de
# Vigilância Sanitária (SNVS) destinados à oferta no território nacional. Atos relacionados:
# ...
# anitária (SNVS) destinados à oferta no território nacional. Atos relacionados:
# RDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos probióticos
# para uso em alimentos.
#
#
# Chunk #12
# Guia nº 55, versão 1, de 25/11/2021  - Guia para avaliação de alegação de propriedade funcional e de
# saúde para substâncias bioativas presentes em alimentos e suplementos alimentares. RDC 241/2018 –
# ...
# de para substâncias bioativas presentes em alimentos e suplementos alimentares. RDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos probióticos para uso
# em alimentos.
#
#
# Chunk #13
# Alterada por:
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes. RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema
# ...
# SNVS) destinados à oferta no território nacional. Ato relacionado:
# Guia nº 21, versão 2, de 05/05/2021  - Guia para Instrução Processual de Petição de Avaliação de
# Probióticos para Uso em Alimentos.
#
#
# Chunk #14
# Documento relacionado:
# Perguntas e Respostas sobre Alteração Taxonômica de Espécies do Gênero Lactobacillus
#
# Guia nº 37, versão 1, de 02/09/2020 - Guia de Especificações de Ingredientes Alimentares
# ...
# illus
#
# Guia nº 37, versão 1, de 02/09/2020 - Guia de Especificações de Ingredientes Alimentares. RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
#
#
# Chunk #15
# RDC 868/2024 - Diretrizes básicas para avaliação de risco e segurança dos alimentos. Atos relacionados:
# RDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos probiótico
# ...
# s para comprovação da segurança e dos benefícios à saúde dos probióticos
# para uso em alimentos. Guia nº 23, versão 1, de 23/07/2019  - Guia para Comprovação da Segurança de Alimentos e
# Ingredientes.
#
#
# Chunk #16
# Documento relacionado:
# Perguntas e Respostas sobre Solicitações Pós -Publicação de Petições de Avaliação da Área de
# Alimentos.
# ...
# Documento relacionado:
# Perguntas e Respostas sobre Solicitações Pós -Publicação de Petições de Avaliação da Área de
# Alimentos.
#
#
# Chunk #17
# 1.3. Padrões microbiológicos para alimentos
#
# Tema Regulatório 3.31 da Agenda Regulatória 2024/2025: Atualização periódica da lista de padrões
# microbiológicos para alimentos. RDC 724/2022 - Padrões
# ...
# Tema Regulatório 3.31 da Agenda Regulatória 2024/2025: Atualização periódica da lista de padrões
# microbiológicos para alimentos. RDC 724/2022 - Padrões microbiológicos dos alimentos e sua aplicação.
#
#
# Chunk #18
# Ato relacionado:
# IN 161/2022 - Padrões microbiológicos dos alimentos. Documento relacionado:
# Perguntas e Respostas sobre Padrões Microbiológicos
#
# IN 161/2022 - Padrões microbiológicos dos alimento
# ...
# o relacionado:
# IN 161/2022 - Padrões microbiológicos dos alimentos. Documento relacionado:
# Perguntas e Respostas sobre Padrões Microbiológicos
#
# IN 161/2022 - Padrões microbiológicos dos alimentos.
#
#
# Chunk #19
# (Atualização Periódica)
# Alterada por:
# IN 313/2024
# 1.4.
# ...
# (Atualização Periódica)
# Alterada por:
# IN 313/2024
# 1.4.
#
#
# Chunk #20
# Irradiação de alimentos
#
# RDC 21/2001 – Regulamento técnico para irradiação de alimentos.
# ...
# Irradiação de alimentos
#
# RDC 21/2001 – Regulamento técnico para irradiação de alimentos.
#
#
# Chunk #21
# 1.5.
# ...
# 1.5.
#
#
# Chunk #22
# Procedimentos para autorização de uso de aditivos alimentares e coadjuvantes
# de tecnologia
#
# Tema Regulatório 3.5 da Agenda Regulatória 2024/2025: Reavaliação da autorização de uso do aditivo
# ali
# ...
# alimentos. Guia nº 43, versão 1, de 14/12/2020  - Procedimentos para Pedidos de Inclusão e Extensão de Uso de Aditivos
# Alimentares e Coadjuvantes de Tecnologia de Fabricação na Legislação Brasileira.
#
#
# Chunk #23
# RDC 725/2022 - Aditivos alimentares aromatizantes. Documento relacionado:
# Perguntas e Respostas sobre Aditivos Aromatizantes de Espécies Botânicas Regionais
#
# RDC 728/2022 - Enzimas e as preparações
# ...
# produção
# de alimentos destinados ao consumo humano. RDC 778/2023 - Princípios gerais, as funções tecnológicas e as condições de uso de aditivos alimentares e
# coadjuvantes de tecnologia em alimentos.
#
#
# Chunk #24
# Alterada por:
#
#
# RDC 826/2023
# RDC 849/2024
# Atos relacionados:
# IN 211/2023
# Guia nº 43, versão 1, de 14/12/2020  - Procedimentos para Pedidos de Inclusão e Extensão de Uso de
# Aditivos Alimentares
# ...
# trientes para levedura destinados ao uso em produtos de panificação e biscoitos. Ato relacionado:
# IN 211/2023
#
# RDC 818/2023 - Requisitos sanitários dos adoçantes de mesa e dos adoçantes dietéticos.
#
#
# Chunk #25
# Alterada por:
# RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de
# Vigilância Sanitária (SNVS) destinados à oferta no território nacional.
# ...
# Alterada por:
# RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de
# Vigilância Sanitária (SNVS) destinados à oferta no território nacional.
#
#
# Chunk #26
# IN 211/2023 - Funções tecnológicas, os limites máximos e as condições de uso para os aditivos alimentares e
# os coadjuvantes de tecnologia autorizados para uso em alimentos.
# ...
# IN 211/2023 - Funções tecnológicas, os limites máximos e as condições de uso para os aditivos alimentares e
# os coadjuvantes de tecnologia autorizados para uso em alimentos.
#
#
# Chunk #27
# (Atualização Periódica)
# Alterada por:
# IN 221/2023
# IN 223/2023
# IN 267/2023
# IN 274/2024
# IN 286/2024
# IN 295/2024
# IN 297/2024
# IN 303/2024
# IN 306/2024
# 1.6.
# ...
# (Atualização Periódica)
# Alterada por:
# IN 221/2023
# IN 223/2023
# IN 267/2023
# IN 274/2024
# IN 286/2024
# IN 295/2024
# IN 297/2024
# IN 303/2024
# IN 306/2024
# 1.6.
#
#
# Chunk #28
# Contaminantes em alimentos
#
# Tema Regulatório 3.17 da Agenda Regulatória 2024/2025: Revisão da regulamentação de contaminantes em
# alimentos.
# ...
# Contaminantes em alimentos
#
# Tema Regulatório 3.17 da Agenda Regulatória 2024/2025: Revisão da regulamentação de contaminantes em
# alimentos.
#
#
# Chunk #29
# Tema Regulatório 3.32 da Agenda Regulatória 2024/2025: Atualização periódica da lista de limites máximos
# tolerados (LMT) de contaminantes em alimentos. RDC 281/2003 – Benzo(a)pireno em alimentos. RDC
# ...
# limentos. RDC 722/2022 - Limites máximos tolerados (LMT) de contaminantes em alimentos, os princípios gerais para o
# seu estabelecimento e os métodos de análise para fins de avaliação de conformidade.
#
#
# Chunk #30
# Ato relacionado:
# IN 160/2022
# Documento relacionado:
#
#
# Documento de Perguntas e Respostas sobre Contaminantes em Alimentos. IN 160/2022 - Limites máximos tolerados (LMT) de contaminantes em alime
# ...
# elacionado:
# IN 160/2022
# Documento relacionado:
#
#
# Documento de Perguntas e Respostas sobre Contaminantes em Alimentos. IN 160/2022 - Limites máximos tolerados (LMT) de contaminantes em alimentos.
#
#
# Chunk #31
# (Atualização Periódica)
# 1.7. Matérias estranhas macroscópicas e microscópicas em alimentos
#
# RDC 623/2022 - Limites de tolerância para matérias estranhas em alimentos, os princípios gerais para o s
# ...
# ntos
#
# RDC 623/2022 - Limites de tolerância para matérias estranhas em alimentos, os princípios gerais para o seu
# estabelecimento e os métodos de análise para fins de avaliação de conformidade. 1.8.
#
#
# Chunk #32
# Resíduos de medicamentos veterinários em alimentos de origem animal
#
# Tema Regulatório 3.33 da Agenda Regulatória 2024/2025: Atualização periódica da lista de LMR, IDA, DRfA
# para IFA de medicamentos
# ...
# s máximos de
# resíduos (LMR) para insumos farmacêuticos ativos (IFA) de medicamentos veterinários em alimentos de
# origem animal. (Atualização Periódica)
# Alterada por:
# IN 241/2023
# IN 317/2024
# 1.9.
#
#
# Chunk #33
# Materiais em contato com alimentos
#
# Tema Regulatório 3.7 da Agenda Regulatória 2024/2025: Regulamentação da reciclagem de materiais
# plásticos em contato com alimentos. Tema Regulatório 3.12 da Age
# ...
# balagens e equipamentos celulósicos destinados a entrar em contato com alimentos. Portaria SVS/MS 27/1996 – Embalagens e equipamentos de vidro e cerâmica destinados a entrar em contato
# com alimentos.
#
#
# Chunk #34
# Alterada por:
# RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de
# Vigilância Sanitária (SNVS) destinados à oferta no território nacional. Portaria SVS/MS 98
# ...
# lietileno tereftalato (PET) destinadas ao
# acondicionamento de bebidas não alcoólicas carbonatadas. RES 105/1999 – Disposições gerais para embalagens e equipamentos plásticos em contato com alimentos.
#
#
# Chunk #35
# Alterada por:
# RDC 51/2010 – Critérios de migração para materiais, embalagens e equipamentos plásticos destinados
# a entrar em contato com alimentos. RDC 52/2010 – Corantes em embalagens e equipamento
# ...
# ntas e Respostas sobre Materiais em contato com alimentos
#
# RDC 122/2001 – Ceras e parafinas em contato com alimentos. RDC 123/2001 – Embalagens e equipamentos elastoméricos em contato com alimentos.
#
#
# Chunk #36
# RDC 124/2001  – Preparados formadores de películas a base de polímeros e/ou resinas destinados ao
# revestimento de Alimentos. RDC 146/2001  – Processo de deposição de camada interna de carbono amorfo
# ...
# ntos. RDC 146/2001  – Processo de deposição de camada interna de carbono amorfo em garrafas de polietileno
# tereftalato (PET). RDC 217/2002 – Películas de celulose regenerada em contato com alimentos.
#
#
# Chunk #37
# Alterada por:
# RDC 755/2022
#
# RDC 218/2002 – Tripas sintéticas de celulose regenerada em contato com Alimentos. RDC 20/2008 – Embalagens de polietileno  tereftalato (PET) pós-consumo reciclado grau a
# ...
# ato com alimentos. Alterada por:
# RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de
# Vigilância Sanitária (SNVS) destinados à oferta no território nacional.
#
#
# Chunk #38
# RDC 51/2010 – Critérios de migração para materiais, embalagens e equipamentos plásticos destinados a entrar
# em contato com alimentos.
# ...
# RDC 51/2010 – Critérios de migração para materiais, embalagens e equipamentos plásticos destinados a entrar
# em contato com alimentos.
#
#
# Chunk #39
# RDC 52/2010  – Corantes em embalagens e equipamentos plásticos destinados a estar em contato com
# alimentos. Alterada por:
# RDC 326/2019
#
# RDC 56/2012 – Lista positiva de monômeros, outras substância
# ...
# amentos plásticos em contato com alimentos. Alterada por:
# RDC 326/2019
# RDC 589/2021
#
# RDC 88/2016  – Materiais, embalagens e equipamentos celulósicos destinados a entrar em contato com
# alimentos.
#
#
# Chunk #40
# Alterada por:
# RDC 589/2021
# RDC 798/2023
#
# RDC 89/2016 – Materiais celulósicos para cocção e filtração a quente. RDC 90/2016  – Materiais, embalagens e equipamentos celulósicos destinados a entrar
# ...
# Lei 9.832/1999 – Proibição do uso industrial de embalagens metálicas soldadas com liga de chumbo e
# estanho para acondicionamento de gêneros alimentícios, exceto para produtos secos ou desidratados.
#
#
# Chunk #41
# 1.10.
# ...
# 1.10.
#
#
# Chunk #42
# Requisitos Sanitários para enriquecimento e restauração de alimentos
#
# RDC 604/2022 - Enriquecimento obrigatório do sal com iodo e das farinhas de trigo e de milho com ferro e
# ácido fólico destinado
# ...
# acionado:
#
#
# Perguntas e Respostas sobre Enriquecimento de Farinhas de Trigo e de Milho com Ferro e Ácido Fólico. RDC 714/2022 - Requisitos sanitários para enriquecimento e restauração de alimentos.
#
#
# Chunk #43
# Alterada por:
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes. RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e
# ...
# 3  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes. RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes. 1.11.
#
#
# Chunk #44
# Requisitos sanitários para alimentos para fins especiais
#
# Tema Regulatório 3.27 da Agenda Regulatória 2024/2025: Revisão e consolidação da regulamentação  sobre
# alimentos infantis, fórmulas para nu
# ...
# infantis, fórmulas para nutrição  enteral e fórmulas dietoterápicas para erros  inatos do
# metabolismo. Portaria SVS/MS 34/1998 – Alimentos de transição para lactentes e crianças de primeira infância.
#
#
# Chunk #45
# Alterada por:
# RDC 42/2011
# RDC 68/2016
# RDC 429/2020
# RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de
# Vigilância Sanitária (SNVS) destinados à oferta no
# ...
# alagens sob competência do Sistema Nacional de
# Vigilância Sanitária (SNVS) destinados à oferta no território nacional. Portaria SVS/MS 36/1998 – Alimentos à base de cereais para alimentação infantil.
#
#
# Chunk #46
# Alterada por:
# RDC 42/2011 – Compostos de nutrientes para alimentos destinados a lactentes e crianças de primeira
# infância.
# ...
# Alterada por:
# RDC 42/2011 – Compostos de nutrientes para alimentos destinados a lactentes e crianças de primeira
# infância.
#
#
# Chunk #47
# RDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos probióticos
# para uso em alimentos. RDC 429/2020 - Rotulagem nutricional dos alimentos embalados.
# ...
# RDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos probióticos
# para uso em alimentos. RDC 429/2020 - Rotulagem nutricional dos alimentos embalados.
#
#
# Chunk #48
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes. RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de
# V
# ...
# istema Nacional de
# Vigilância Sanitária (SNVS) destinados à oferta no território nacional. RDC 42/2011 – Compostos de nutrientes para alimentos destinados a lactentes e crianças de primeira infância.
#
#
# Chunk #49
# Alterada por:
# RDC 45/2014
#
# RDC 43/2011 – Fórmulas infantis para lactentes. RDC 44/2011 – Fórmulas infantis de seguimento para lactentes e crianças de primeira infância. RDC 45/2011  – Fórmulas infa
# ...
# específicas e
# fórmulas infantis de seguimento para lactentes e crianças de primeira infância destinadas a necessidades
# dietoterápicas específicas. Alteradas por:
# RDC 46/2014 – Altera a RDC 43/2011.
#
#
# Chunk #50
# RDC 47/2014 – Altera a RDC 44/2011. RDC 48/2014 – Altera a RDC 45/2011. RDC 241/2018 – Altera as RDC´s 43 e 44/2011.
# ...
# RDC 47/2014 – Altera a RDC 44/2011. RDC 48/2014 – Altera a RDC 45/2011. RDC 241/2018 – Altera as RDC´s 43 e 44/2011.
#
#
# Chunk #51
# RDC 429/2020 – Altera as RDC´s 43, 44, 45/2011. RDC 729/2022 - Melhora da técnica legislativa e revogação de normas inferiores a Decreto editadas
# pela ANVISA, componentes da quinta etapa de consolida
# ...
# cia temática de alimentos em
# observância ao que prevê a Portaria nº 488/GADIP -DP/ANVISA, de 23 de setembro de 2021 e o
# Decreto nº 10.139, de 28 de novembro de 2019. Altera as RDC´s 43, 44, 45/2011.
#
#
# Chunk #52
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes. Documento relacionado:
# Perguntas e Respostas sobre Fórmulas Infantis.
# ...
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes. Documento relacionado:
# Perguntas e Respostas sobre Fórmulas Infantis.
#
#
# Chunk #53
# RDC 21/2015 – Fórmulas para nutrição enteral.
# ...
# RDC 21/2015 – Fórmulas para nutrição enteral.
#
#
# Chunk #54
# RDC 22/2015 – Compostos de nutrientes e de outras substâncias para fórmulas para nutrição enteral. Alteradas por:
# RDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos
# ...
# cias para fórmulas para nutrição enteral. Alteradas por:
# RDC 241/2018 – Requisitos para comprovação da segurança e dos benefícios à saúde dos probióticos
# para uso em alimentos. Altera a RDC 22/2015.
#
#
# Chunk #55
# RDC 401/2020 - Altera a RDC  22/2015 para atualizar as referências de especificações para  compostos
# fontes de nutrientes e outras substâncias para uso em fórmulas para nutrição enteral. RDC 429/2020
# ...
# specificações para  compostos
# fontes de nutrientes e outras substâncias para uso em fórmulas para nutrição enteral. RDC 429/2020 - Rotulagem nutricional dos alimentos embalados. Altera a RDC 21/2015.
#
#
# Chunk #56
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes. Altera a RDC 22/2015.
# ...
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes. Altera a RDC 22/2015.
#
#
# Chunk #57
# Documento relacionado:
# Perguntas e Respostas sobre Fórmulas para Nutrição Enteral. RDC 460/2020 - Requisitos sanitários das fórmulas dietoterápicas para erros inatos do metabolismo. Alterada por:
# RD
# ...
# s para Nutrição Enteral. RDC 460/2020 - Requisitos sanitários das fórmulas dietoterápicas para erros inatos do metabolismo. Alterada por:
# RDC 429/2020 - Rotulagem nutricional dos alimentos embalados.
#
#
# Chunk #58
# RDC 729/2022 - Melhora da técnica legislativa e revogação de normas inferiores a Decreto editadas
# pela ANVISA, componentes da quinta etapa de consolidação da pertinência temática de alimentos em
# obs
# ...
# a Portaria nº 488/GADIP -DP/ANVISA, de 23 de setembro de 2021 e o
# Decreto nº 10.139, de 28 de novembro de 2019. RDC 818/2023 - Requisitos sanitários dos adoçantes de mesa e dos adoçantes dietéticos.
#
#
# Chunk #59
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes. RDC 843/2024 - Regularização de alimentos e embalagens sob competência do Sistema Nacional de
# V
# ...
# dietas com restrição de nutrientes e dos alimentos para dietas de ingestão controlada de açúcares. Alterada por:
# RDC 818/2023 - Requisitos sanitários dos adoçantes de mesa e dos adoçantes dietéticos.
#
#
# Chunk #60
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes.
# ...
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes.
#
#
# Chunk #61
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes. 1.12. Requisitos sanitários para suplementos alimentares
#
# Tema Regulatório 3.29 da Agenda Regula
# ...
# ria (SNVS) destinados à oferta no território nacional. Ato relacionado:
# IN 28/2018 – Listas de constituintes, de limites de uso, de alegações e de rotulagem complementar dos
# suplementos alimentares.
#
#
# Chunk #62
# Documentos relacionados:
# Perguntas e Respostas sobre Suplementos Alimentares. Perguntas e Respostas sobre Substâncias Bioativas. IN 28/2018  – Listas de constituintes, de limites de uso, de alegações
# ...
# ementos Alimentares. Perguntas e Respostas sobre Substâncias Bioativas. IN 28/2018  – Listas de constituintes, de limites de uso, de alegações e de rotulagem complementar dos
# suplementos alimentares.
#
#
# Chunk #63
# (Atualização Periódica)
# Alterada por:
# IN 76/2020 – Atualiza as listas de constituintes, de limites de uso, de alegações e de rotulagem
# complementar dos suplementos alimentares. IN 102/2021
# IN 275/
# ...
# ar dos suplementos alimentares. IN 102/2021
# IN 275/2024
# IN 284/2024
# IN 304/2024
# IN 318/2024
#
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
#
#
# Chunk #64
# 1.13.
# ...
# 1.13.
#
#
# Chunk #65
# Requisitos para uso de gordura trans industrial em alimentos
# RDC 632/2022 - Restrição de uso de gorduras trans industriais em alimentos. Documento relacionado:
# Perguntas e Respostas – Requisitos par
# ...
# m alimentos
# RDC 632/2022 - Restrição de uso de gorduras trans industriais em alimentos. Documento relacionado:
# Perguntas e Respostas – Requisitos para uso de Gorduras Trans Industriais em Alimentos.
#
#
# Chunk #66
# 1.14. Requisitos sanitários para amidos, biscoitos, cereais integrais, cereais
# processados, farelos, farinhas, farinhas integrais, massas alimentícias e pães
#
# RDC 604/2022 - Enriquecimento obrigató
# ...
# processados, farelos,
# farinhas, farinhas integrais, massas alimentícias e pães. Alterada por:
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes.
#
#
# Chunk #67
# RDC 712/2022 - Requisitos de composição e rotulagem dos alimentos contendo cereais e pseudocereais para
# classificação e identificação como integral e para destaque da presença de ingredientes integra
# ...
# e ingredientes integrais. Documento relacionado:
# Perguntas e Respostas sobre Cereais Integrais
#
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
#
#
# Chunk #68
# 1.15. Requisitos sanitários para açúcares, bala, bombom, cacau em pó, cacau
# solúvel, chocolate, chocolate branco, goma de mascar, manteiga de cacau,
# massa de cacau, melaço, melado e rapadura
#
# RDC
# ...
# , chocolate branco, goma de mascar, manteiga de cacau, massa de
# cacau, melaço, melado e rapadura. Alterada por:
# RDC 818/2023 - Requisitos sanitários dos adoçantes de mesa e dos adoçantes dietéticos.
#
#
# Chunk #69
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes.
# ...
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes.
#
#
# Chunk #70
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
# ...
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
#
#
# Chunk #71
# 1.16. Requisitos sanitários para g elados comestíveis e preparados para gelados
# comestíveis
#
# RDC 713/2022 - Requisitos sanitários dos gelados comestíveis e dos preparados para gelados comestíveis.
# ...
# tos sanitários dos gelados comestíveis e dos preparados para gelados comestíveis. Alterada por:
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes.
#
#
# Chunk #72
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
# ...
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
#
#
# Chunk #73
# 1.17. Requisitos sanitários para cogumelos, produtos de frutas e produtos de
# vegetais
#
# RDC 726/2022 - Requisitos sanitários dos cogumelos comestíveis, dos produtos de frutas e dos produtos de
# vege
# ...
# os dos cogumelos comestíveis, dos produtos de frutas e dos produtos de
# vegetais. Alterada por:
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes.
#
#
# Chunk #74
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
# ...
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
#
#
# Chunk #75
# 1.18. Requisitos sanitários para óleos e gorduras vegetais
#
# Tema Regulatório 3.30 da Agenda Regulatória 2024/2025: Atualização periódica da lista de espécies vegetais
# autorizadas, as designações, a
# ...
# VISA, de 23 de setembro de 2021 e o
# Decreto nº 10.139, de 28 de novembro de 2019. RDC 829/2023
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes.
#
#
# Chunk #76
# Ato relacionado:
# IN 87/2021  - Estabelece a lista de espécies vegetais autorizadas, as designações, a composição de
# ácidos graxos e os valores máximos de acidez e de índice de peróxidos para óleos e
# ...
# N 87/2021  - Estabelece a lista de espécies vegetais autorizadas, as designações, a composição de ácidos
# graxos e os valores máximos de acidez e de índice de peróxidos para óleos e gorduras vegetais.
#
#
# Chunk #77
# Alterada por:
# IN 311/2024
# 1.19.
# ...
# Alterada por:
# IN 311/2024
# 1.19.
#
#
# Chunk #78
# Requisitos sanitários para palmito em conserva
#
# RDC 18/1999 - Processo de industrialização e comercialização de palmitos. Alterada por:
# RDC 7/2000 – Certificado de Boas Práticas de Fabricação e con
# ...
# etapa de consolidação da pertinência temática de alimentos em
# observância ao que prevê a Portaria nº 488/GADIP -DP/ANVISA, de 23 de setembro de 2021 e o
# Decreto nº 10.139, de 28 de novembro de 2019.
#
#
# Chunk #79
# RDC 726/2022 - Requisitos sanitários dos cogumelos comestíveis, dos produtos de frutas e dos produtos de
# vegetais.
# ...
# RDC 726/2022 - Requisitos sanitários dos cogumelos comestíveis, dos produtos de frutas e dos produtos de
# vegetais.
#
#
# Chunk #80
# Alterada por:
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes.
# ...
# Alterada por:
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes.
#
#
# Chunk #81
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes. 1.20. Requisitos sanitários para misturas para o preparo de alimentos e alimentos
# prontos para co
# ...
# das misturas para o preparo de alimentos e dos alimentos prontos para o
# consumo. Alterada por:
# RDC 839/2023  - Comprovação de segurança e autorização de uso de novos alimentos e novos
# ingredientes.
#
#
# Chunk #82
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
# ...
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
#
#
# Chunk #83
# 1.21. Requisitos sanitários para águas envasadas e gelo destinados ao consumo
# humano
#
# Decreto-Lei nº 7.841/1945 – Código de águas minerais. RDC 717/2022 - Requisitos sanitários das águas envasadas
# ...
# o
# especiarias. (Atualização Periódica)
# Alterada por:
# IN 197/2022
# IN 262/2023
# IN 273/2024
#
# RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
#
#
# Chunk #84
# 1.23. Requisitos sanitários para sal destinado ao consumo humano
#
# Lei 6.150/1974 – Dispõe sobre a obrigatoriedade da iodação do sal, destinado ao consumo humano, seu
# controle pelos órgãos sanitário
# ...
# e qualidade para o sal destinado ao consumo humano. RDC 604/2022 - Enriquecimento obrigatório do sal com iodo e das farinhas de trigo e de milho com ferro e
# ácido fólico destinados ao consumo humano.
#
#
# Chunk #85
# Alterada por:
# RDC 612/2022
# 1.24.
# ...
# Alterada por:
# RDC 612/2022
# 1.24.
#
#
# Chunk #86
# Requisitos Sanitários dos alimentos nutricionalmente modificados
#
# RDC 720/2022 - Requisitos sanitários dos alimentos nutricionalmente modificados. Alterada por:
# RDC 839/2023  - Comprovação de segur
# ...
# respostas sobre modificações na composição de alimentos padronizados para alegações
# nutricionais. RDC 839/2023 - Comprovação de segurança e autorização de uso de novos alimentos e novos ingredientes.
#
#
# Chunk #87
# 1.25.
# ...
# 1.25.
#
#
# Chunk #88
# Admissibilidade de análise realizada por Autoridade Reguladora Estrangeira
# Equivalente (AREE)
#
# Tema Regulatório 3.1 da Agenda Regulatória 2024/2025 - A regulamentar. 1.26.
# ...
# Admissibilidade de análise realizada por Autoridade Reguladora Estrangeira
# Equivalente (AREE)
#
# Tema Regulatório 3.1 da Agenda Regulatória 2024/2025 - A regulamentar. 1.26.
#
#
# Chunk #89
# Regulamentação dos alimentos para fins médicos
#
# Tema Regulatório 3.10 da Agenda Regulatória 2024/2025 - A regulamentar. 1.27. Regulamentação dos alimentos plant-based
#
# Tema Regulatório 3.11 da Age
# ...
# Tema Regulatório 3.10 da Agenda Regulatória 2024/2025 - A regulamentar. 1.27. Regulamentação dos alimentos plant-based
#
# Tema Regulatório 3.11 da Agenda Regulatória 2024/2025 - A regulamentar. 2.
#
#
# Chunk #90
# Informações ao consumidor
# 2.1. Rotulagem de Alimentos
#
# Tema Regulatório 3.3 da Agenda Regulatória 2024/2025: Identificação de estratégias para promover o
# acesso a informações necessárias ao cons
# ...
# s embalados. Tema 3.25 da Agenda Regulatória 2024/2025: Revisão da regulamentação sobre rotulagem  nutricional dos
# alimentos embalados. Decreto-Lei 986/1969 – Institui normas básicas sobre alimentos.
#
#
# Chunk #91
# Alterado por:
# Lei 13.305/2016 – Altera Decreto-Lei 986/1969 para dispor sobre rotulagem de alimentos com lactose. Decreto 4.680/2003 – Regulamenta o direito à informação  quanto aos alimentos e ingre
# ...
# tinados ao consumo humano ou animal que contenham ou sejam produzidos a partir de organismos
# geneticamente modificados. Ato relacionado:
# Portaria MJ 2.658/2003 – Define o símbolo de que trata o art.
#
#
# Chunk #92
# 2º, § 1º, do Decreto 4.680, de 24 de abril
# de 2003.
# ...
# 2º, § 1º, do Decreto 4.680, de 24 de abril
# de 2003.
#
#
# Chunk #93
# Lei 10.674/2003  – Obriga a que os produtos alimentícios comercializados informem sobre a presença de
# glúten, como medida preventiva e de controle da doença celíaca. Lei 11.265/2006 – Regulamenta a c
# ...
# ida preventiva e de controle da doença celíaca. Lei 11.265/2006 – Regulamenta a comercialização de alimentos para lactentes e crianças de primeira infância
# e a de produtos de puericultura correlatos.
#
#
# Chunk #94
# Alterada por:
# Lei 11.474/2007  – Altera a Lei no 10.188, de 12 de fevereiro de 2001, que cria o Programa de
# Arrendamento Residencial, institui o arrendamento residencial com opção de compra, e a Lei
# ...
# adolescente e do aprendiz, e sobre o Conselho Nacional
# dos Direitos da Criança e do Adolescente, o Fundo Nacional para a Criança e o Adolescente e os
# programas federais da criança e do adolescente.
#
#
# Chunk #95
# INC 9/2002 – Embalagens destinadas ao acondicionamento de produtos hortícolas ''in natura''.
# ...
# INC 9/2002 – Embalagens destinadas ao acondicionamento de produtos hortícolas ''in natura''.
#
#
# Chunk #96
# RDC 21/2001 – Regulamento técnico para irradiação de alimentos.
# ...
# RDC 21/2001 – Regulamento técnico para irradiação de alimentos.
#
#
# Chunk #97
# RDC 429/2020 - Rotulagem nutricional dos alimentos embalados. Alterada por:
# RDC 460/2020 - Requisitos sanitários das fórmulas dietoterápicas para erros inatos do metabolismo. RDC 729/2022 - Melhora d
# ...
# 021 e o
# Decreto nº 10.139, de 28 de novembro de 2019. RDC 819/2023
# Ato relacionado:
# IN 75/2020 - Estabelece os requisitos técnicos para declaração da rotulagem nutricional nos alimentos
# embalados.
#
#
# Chunk #98
# Documentos relacionados:
# Perguntas e Respostas sobre Rotulagem Nutricional de Alimentos embalados
# Perguntas e Respostas sobre Alegações Nutricionais
#
# IN 75/2020  - Estabelece os requisitos técni
# ...
# requisitos técnicos para declaração da rotulagem nutricional nos alimentos
# embalados. Alterada por:
# RDC 460/2020 - Requisitos sanitários das fórmulas dietoterápicas para erros inatos do metabolismo.
#
#
# Chunk #99
# RDC 727/2022 - Rotulagem dos alimentos embalados. Atos relacionados:
# Lei 12.849/2013 – Obrigatoriedade de as fábricas de produtos que contenham látex natural gravarem
# em suas embalagens advertência
# ...
# dvertência sobre a presença dessa substância. RDC 902/2024  - Inclusão de declaração sobre nova fórmula na rotulagem de produtos sujeitos à
# vigilância sanitária quando da alteração de sua composição.

# %%
import os

# Create the new folder if it doesn't exist
os.makedirs("Semantic_Chunks", exist_ok=True)

# Split the text into chunks
#chunks = text_splitter.split_text(texto_pdf)

# Save each chunk into an individual .txt file
for i, chunk in enumerate(chunks):
    chunk_filename = f"Semantic_Chunks/chunk_{i+1}.txt"
    with open(chunk_filename, "w", encoding="utf-8") as chunk_file:
        chunk_file.write(chunk)

print(f"Saved {len(chunks)} chunks into the 'Sematic_Chunks' folder.")
# Out:
# Saved 132 chunks into the 'Sematic_Chunks' folder.
